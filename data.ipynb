# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\Pooja\Downloads\car prediction.csv")
data
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    str
#  1   company     892 non-null    str
#  2   year        892 non-null    str
#  3   Price       892 non-null    str
#  4   kms_driven  840 non-null    str
#  5   fuel_type   837 non-null    str
# dtypes: str(6)
# memory usage: 41.9 KB

# %%
data.isnull()
# Out:
#       name  company   year  Price  kms_driven  fuel_type
# 0    False    False  False  False       False      False
# 1    False    False  False  False       False      False
# 2    False    False  False  False       False      False
# 3    False    False  False  False       False      False
# 4    False    False  False  False       False      False
# ..     ...      ...    ...    ...         ...        ...
# 887  False    False  False  False        True       True
# 888  False    False  False  False       False      False
# 889  False    False  False  False       False      False
# 890  False    False  False  False       False       True
# 891  False    False  False  False       False       True
#
# [892 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='str')

# %%
data.shape
# Out:
# (892, 6)

# %%
data.describe()
# Out:
#               name company  year          Price  kms_driven fuel_type
# count          892     892   892            892         840       837
# unique         525      48    61            274         258         3
# top     Honda City  Maruti  2015  Ask For Price  45,000 kms    Petrol
# freq            13     235   117             35          30       440

# %%
data["year"].unique()
# Out:
# <StringArray>
# ['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016', '2010',
#  '2017', '2008', '2011', '2019', '2009', '2005', '2000',  '...', '150k',
#  'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs', 'sale', '1995', 'ara)',
#  '2002', 'SELL', '2001', 'tion', 'odel', '2 bs', 'arry',  'Eon', 'o...',
#  'ture',  'emi',  'car', 'able',  'no.', 'd...', 'SALE', 'digo', 'sell',
#  'd Ex', 'n...', 'e...', 'D...', ', Ac', 'go .', 'k...', 'o c4', 'zire',
#  'cent', 'Sumo',  'cab', 't xe',  'EV2', 'r...', 'zest']
# Length: 61, dtype: str

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Length: 892, dtype: bool

# %%
data.drop_duplicates(keep="first", inplace= True)

# %%
data.shape
# Out:
# (798, 6)

# %%
data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    50
# fuel_type     53
# dtype: int64

# %%
#cleaning data
data1= data.copy(deep=True)

# %%
data.year.str.isnumeric()# checks numeric values
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 887    False
# 888     True
# 889     True
# 890     True
# 891     True
# Name: year, Length: 798, dtype: bool

# %%
data=data[data.year.str.isnumeric()]# converts into numeric value

# %%
data
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
data.year.unique()
# Out:
# <StringArray>
# ['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016', '2010',
#  '2017', '2008', '2011', '2019', '2009', '2005', '2000', '2003', '2004',
#  '1995', '2002', '2001']
# Length: 21, dtype: str

# %%
data.year.info()
# Out:
# <class 'pandas.Series'>
# Index: 749 entries, 0 to 891
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 749 non-null    str
# dtypes: str(1)
# memory usage: 11.7 KB

# %%
data["year"]=data.year.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 749 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        749 non-null    str
#  1   company     749 non-null    str
#  2   year        749 non-null    int64
#  3   Price       749 non-null    str
#  4   kms_driven  748 non-null    str
#  5   fuel_type   745 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 41.0 KB

# %%
data.Price.unique()
# Out:
# <StringArray>
# [       '80,000',      '4,25,000', 'Ask For Price',      '3,25,000',
#       '5,75,000',      '1,75,000',      '1,90,000',      '8,30,000',
#       '2,50,000',      '1,82,000',
#  ...
#         '42,000',      '1,89,000',      '1,62,000',        '35,999',
#      '29,00,000',        '39,999',        '50,500',      '5,10,000',
#       '8,60,000',      '5,00,001']
# Length: 273, dtype: str

# %%
x='80,000'
x=x.replace(',','')

# %%
x
# Out:
# '80000'

# %%
data.Price.str.isnumeric()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Price, Length: 749, dtype: bool

# %%
data.Price.str.replace(',','').str.isnumeric()
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 886     True
# 888     True
# 889     True
# 890     True
# 891     True
# Name: Price, Length: 749, dtype: bool

# %%
data=data[data.Price.str.replace(',','').str.isnumeric()]

# %%
data["Price"]=data["Price"].str.replace(',','')

# %%
data
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# ...

# %%
data.Price.dtype
# Out:
# dtype('int64')

# %%
data['Price']= data['Price'].astype(int)

# %%
data["kms_driven"].unique()
# Out:
# <StringArray>
# [  '45,000 kms',       '40 kms',   '28,000 kms',   '36,000 kms',
#    '41,000 kms',   '25,000 kms',   '24,530 kms',   '60,000 kms',
#    '30,000 kms',   '32,000 kms',
#  ...
#    '33,400 kms',   '60,123 kms', '1,37,495 kms',   '91,200 kms',
#  '1,46,000 kms', '1,00,800 kms',    '2,100 kms',    '2,500 kms',
#  '1,32,000 kms',       'Petrol']
# Length: 250, dtype: str

# %%
'1,32,000 kms'.split()[0]
# Out:
# '1,32,000'

# %%
'1,32,000 kms'.replace(',','').split()[0]
# Out:
# '132000'

# %%
data['kms_driven']= data['kms_driven'].apply(lambda x:x.replace(',','').split()[0])

# %%
data
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 886                    Toyota Corolla Altis     Toyota  2009  300000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#     kms_driven fuel_type
# 0        45000    Petrol
# 1           40    Diesel
# 3        28000    Petrol
# 4        36000    Diesel
# ...

# %%
data=data[data['kms_driven'].str.isnumeric()]

# %%
data['kms_driven']=data['kms_driven'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 725 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        725 non-null    str
#  1   company     725 non-null    str
#  2   year        725 non-null    str
#  3   Price       725 non-null    int64
#  4   kms_driven  725 non-null    int64
#  5   fuel_type   724 non-null    str
# dtypes: int64(2), str(4)
# memory usage: 39.6 KB

# %%
data.fuel_type.value_counts()
# Out:
# fuel_type
# Petrol    390
# Diesel    332
# LPG         2
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     1
# dtype: int64

# %%
data[data.isnull().any(axis=1)]
# Out:
#                name company  year   Price  kms_driven fuel_type
# 132  Toyota Corolla  Toyota  2009  275000       26000       NaN

# %%
data[data['company']=='Toyota'].fuel_type.mode()
# Out:
# 0    Diesel
# Name: fuel_type, dtype: str

# %%
data['fuel_type']=data.fuel_type.fillna('Diesel')

# %%
data.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.boxplot(data["Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2028d56ee90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2028d56f110>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2028d56ed50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2028d56f390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2028d56f4d0>],
#  'means': []}

# %%
data["Price"].max()
# Out:
# np.int64(8500003)

# %%
data[data["Price"]==data['Price'].max()]
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 562  Mahindra XUV500 W6  Mahindra  2014  8500003       45000    Diesel

# %%
data[data['name']=='Mahindra XUV500 W6']
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 484  Mahindra XUV500 W6  Mahindra  2013   548900       49800    Diesel
# 562  Mahindra XUV500 W6  Mahindra  2014  8500003       45000    Diesel
# 586  Mahindra XUV500 W6  Mahindra  2013   549900       52800    Diesel

# %%
data.loc[562,'Price']=850000

# %%
# evaluation matrix IN REGRESSION
1. RMSE 
2. MSE- MEAN SQUARE ERROR 
3. R SQUARED , AVERAGE R SQUARE
4. MAE

# %%
# EVALUATION MATRIX IN CLASSIFICATION
1. PRECISION
2. RECALL
3. ACCURACY
4. F1 SCORE - TAKES BOTH PRECISION AND RECALL 
5. ROC ACCURACY
6. PRECISION = TP/TP+FP 
7. RECALL= TP/TP+TN 
IN ANY MEDICAL DATA FN SHOULD BE LESS
IN SPAM CLASSIFICATION FP SHOULD BE LESS

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import joblib

# %%
# load the data
data = pd.read_csv(r"C:\Users\Pooja\OneDrive\Desktop\car price prediction\cleaned_data.csv")

# %%
# Basic cleaning (adapt if already cleaned)
data = data.dropna()

X = data[['name', 'company', 'year', 'kms_driven', 'fuel_type']]
y = data['Price']

# %%
# Preprocessing
categorical = ['name', 'company', 'fuel_type']
numeric = ['year', 'kms_driven']

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical),
        ('num', 'passthrough', numeric)
    ]
)

# %%
# Model pipeline
model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# Train
model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['name', 'company',
#                                                    'fuel_type']),
#                                                  ('num', 'passthrough',
#                                                   ['year', 'kms_driven'])])),
#                 ('regressor', LinearRegression())])

# %%
# Save model
joblib.dump(model, "car_price_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!
